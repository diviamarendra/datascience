# %%
import seaborn as sns
sns.set()
sns.set(style = "darkgrid")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Out:
# b'Skipping line 418: expected 36 fields, saw 37\nSkipping line 614: expected 36 fields, saw 37\nSkipping line 822: expected 36 fields, saw 37\nSkipping line 825: expected 36 fields, saw 37\nSkipping line 1092: expected 36 fields, saw 37\nSkipping line 1481: expected 36 fields, saw 37\nSkipping line 1484: expected 36 fields, saw 37\nSkipping line 1600: expected 36 fields, saw 37\nSkipping line 1601: expected 36 fields, saw 37\nSkipping line 1606: expected 36 fields, saw 37\nSkipping line 1677: expected 36 fields, saw 37\nSkipping line 1678: expected 36 fields, saw 37\nSkipping line 1679: expected 36 fields, saw 37\nSkipping line 1786: expected 36 fields, saw 37\nSkipping line 1790: expected 36 fields, saw 37\nSkipping line 2190: expected 36 fields, saw 37\nSkipping line 2768: expected 36 fields, saw 37\nSkipping line 2790: expected 36 fields, saw 37\nSkipping line 2818: expected 36 fields, saw 37\nSkipping line 2978: expected 36 fields, saw 37\nSkipping line 2979: expected 36 fields, 
# ...

# %%
emp_by_type = data_sdh.groupby('IS_SCHNEIDER_EMP')

# %%
emp_by_type.first()
# Out:
#                  ID$ FULL_NAME CELL       COMPANY_CODE   PHONE SESITE_ID$  \
# IS_SCHNEIDER_EMP
# 'No'              ''    'CN01'   ''  '100000000014033'  'TET3'       'TE'
# 'Yes'             ''    'CN01'   ''  '100000000012129'  'TST4'       'TS'
#
#                  JOB_CODE       JOB_SUB_FUNCTION JOB_FUNCTION COMPANY  ...  \
# IS_SCHNEIDER_EMP                                                       ...
# 'No'                  'T'  'Sch Elec (China) Co.        Ltd.'   'ITB'  ...
# 'Yes'                 'T'  'Sch Elec (China) Co.        Ltd.'   'EMG'  ...
#
#                  LAST_NAME SEWORK_ID$_REPORTS_TO PREF_FIRST_NAME  \
# IS_SCHNEIDER_EMP
# 'No'               'Zhang'          'SESA505752'              ''
# 'Yes'               'ZHAO'          'SESA370652'        'Daniel'
#
#                  ORIGNAL_HIRE_DATE   COST_CENTER COUNTRY_CODE  \
# IS_SCHNEIDER_EMP
# 'No'                  '2020-10-12'  'SECP721601'         'CN'
# ...

# %%
pd.crosstab(data_sdh["COMPANY"],data_sdh['IS_SCHNEIDER_EMP'],margins=True)
# Out:
# IS_SCHNEIDER_EMP                      'No'  'Yes'    All
# COMPANY
# ''                                       0     66     66
# 'APOD'                                   3      0      3
# 'AVE'                                   26      2     28
# 'BLG'                                  170    106    276
# 'Building Business'                      0      6      6
# ...                                    ...    ...    ...
# 'Software AVEVA'                        10      4     14
# 'Strategy & Sustainability Business'     0     28     28
# 'TEC'                                    3     13     16
# 'ZZZ0'                                   0      1      1
# All                                   1192   8996  10188
#
# [66 rows x 3 columns]

# %%
sns.lineplot(x = "IS_SCHNEIDER_EMP", y = count('FULL_NAME'),data = data_sdh[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-40083c63f2cd> in <module>
# ----> 1 sns.lineplot(x = "IS_SCHNEIDER_EMP", y = count('FULL_NAME'),data = data_sdh[:10])
#
# NameError: name 'count' is not defined
